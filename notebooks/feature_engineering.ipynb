# %%
from helper.data_handling import data_from_file
import numpy as np

def get_raw_data():
    return data_from_file("../data/stroke_raw.csv")

# %%
def insert_error(df, fault_perc):

    for col in df.columns:
        num_missing = int(len(df) * fault_perc)
        rows_missing = np.random.choice(df.index, num_missing, replace=False)
        cols_missing = np.random.choice(df.columns, num_missing, replace=True)
        for row, col in zip(rows_missing, cols_missing):
            df.at[row, col] = np.nan
    return df
    
    print("Inserting errors")

def impute_data(df):
    
    print("Imputing data")
    

insert_error(get_raw_data(), 0.2)
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        NaN  67.0           NaN            1.0          NaN        Private
# 1        NaN   NaN           NaN            0.0          NaN  Self-employed
# 2        NaN  80.0           NaN            1.0          NaN            NaN
# 3        NaN   NaN           0.0            0.0          NaN        Private
# 4     Female   NaN           1.0            0.0          NaN            NaN
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female   NaN           NaN            NaN          NaN            NaN
# 5106     NaN   NaN           0.0            0.0          NaN            NaN
# 5107     NaN   NaN           NaN            0.0          NaN  Self-employed
# 5108    Male   NaN           NaN            NaN          Yes            NaN
# 5109     NaN  44.0           NaN            0.0          Yes            NaN
#
# ...
